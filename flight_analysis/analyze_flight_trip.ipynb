# %% [markdown]
# <a href="https://colab.research.google.com/github/rave-dev-01/data-science-folio/blob/main/analyze_flight_trip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy
import plotly
import folium

# %%
m24flight = pd.read_csv('mar24_flight.csv')
m24flight
# Out:
#             Date       Time        Lat        Lon   Speed Data (miles/hour)  \
# 0     2025-03-24   14:00:43  34.645025 -86.775467                     10.56
# 1     2025-03-24   14:00:44  34.645044 -86.775509                     10.18
# 2     2025-03-24   14:00:45  34.645044 -86.775559                     10.18
# 3     2025-03-24   14:00:46  34.645048 -86.775608                     10.18
# 4     2025-03-24   14:00:47  34.645054 -86.775663                     10.33
# ...          ...        ...        ...        ...                       ...
# 3098  2025-03-24   15:19:04  38.883916 -78.088035                    342.31
# 3099  2025-03-24   15:19:05  38.884345 -78.086328                    342.06
# 3100  2025-03-24   15:19:06  38.884768 -78.084651                    342.15
# 3101  2025-03-24   15:19:07  38.885190 -78.082973                    342.11
# 3102  2025-03-24   15:19:08  38.885614 -78.081293                    342.12
#
#        Elevation (m)
# 0             189.24
# ...

# %%
m = folium.Map()
m.save("footprint.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m24_flight.describe()
# Out:
#                Lat          Lon  Speed Data (miles/hour)  Elevation (m)
# count  3103.000000  3103.000000              3103.000000    3103.000000
# mean     37.012005   -83.098699               454.448205    5595.566487
# std       1.588985     2.899215               210.484882    3009.122817
# min      34.618285   -86.782795                 0.000000     163.680000
# 25%      34.973934   -86.508040               362.720000    3052.940000
# 50%      37.759395   -82.945618               562.830000    7542.110000
# 75%      38.299957   -80.495136               613.410000    7571.885000
# max      38.885614   -78.081293               853.480000    9439.920000
